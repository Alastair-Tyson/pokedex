# %%
import pandas as pd

# %%
df=pd.read_csv('pokedex_basic.csv').set_index('PokedexNumber')
df
# Out:
#                                 Name          Type  Total  HP  Attack  \
# PokedexNumber
# 1                          Bulbasaur   GrassPoison    318  45      49
# 2                            Ivysaur   GrassPoison    405  60      62
# 3                           Venusaur   GrassPoison    525  80      82
# 3              VenusaurMega Venusaur   GrassPoison    625  80     100
# 4                         Charmander          Fire    309  39      52
# ...                              ...           ...    ...  ..     ...
# 719                          Diancie     RockFairy    600  50     100
# 719              DiancieMega Diancie     RockFairy    700  50     160
# 720              HoopaHoopa Confined  PsychicGhost    600  80     110
# 720               HoopaHoopa Unbound   PsychicDark    680  80     160
# 721                        Volcanion     FireWater    600  80     110
#
#                Defense  SpecialAttack  SpecialDefense  Speed
# PokedexNumber
# ...

# %%
df[df.Name=='Groudon']
# Out:
#                   Name    Type  Total   HP  Attack  Defense  SpecialAttack  \
# PokedexNumber
# 383            Groudon  Ground    670  100     150      140            100
#
#                SpecialDefense  Speed
# PokedexNumber
# 383                        90     90

# %%
df.groupby('Type').mean()
# Out:
#                    Total         HP      Attack     Defense  SpecialAttack  \
# Type
# Bug           289.705882  53.058824   50.352941   55.411765      39.294118
# BugElectric   395.500000  60.000000   62.000000   55.000000      77.000000
# BugFighting   550.000000  80.000000  155.000000   95.000000      40.000000
# BugFire       455.000000  70.000000   72.500000   60.000000      92.500000
# BugFlying     419.500000  63.000000   70.142857   61.571429      72.857143
# ...                  ...        ...         ...         ...            ...
# WaterIce      511.666667  90.000000   83.333333  113.333333      80.000000
# WaterPoison   426.666667  61.666667   68.333333   58.333333      61.666667
# WaterPsychic  481.000000  87.000000   73.000000  104.000000      94.000000
# WaterRock     428.750000  70.750000   82.750000  112.750000      61.500000
# WaterSteel    530.000000  84.000000   86.000000   88.000000     111.000000
#
#               SpecialDefense      Speed
# Type
# ...

# %%
pivot.to_csv('some_name.csv')

# %%
pivot.Total.plot(kind='bar')
