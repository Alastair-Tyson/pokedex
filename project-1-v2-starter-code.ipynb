# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Building-&quot;Pokemon-Stay&quot;" data-toc-modified-id="Building-&quot;Pokemon-Stay&quot;-0.1">Building "Pokemon Stay"</a></span><ul class="toc-item"><li><span><a href="#Package-imports" data-toc-modified-id="Package-imports-0.1.1">Package imports</a></span></li></ul></li></ul></li><li><span><a href="#1.-Defining-a-player" data-toc-modified-id="1.-Defining-a-player-1">1. Defining a player</a></span></li><li><span><a href="#2.-Defining-&quot;gym&quot;-locations" data-toc-modified-id="2.-Defining-&quot;gym&quot;-locations-2">2. Defining "gym" locations</a></span></li><li><span><a href="#3.-Create-a-pokedex" data-toc-modified-id="3.-Create-a-pokedex-3">3. Create a pokedex</a></span></li><li><span><a href="#4.-Create-a-data-structure-for-players" data-toc-modified-id="4.-Create-a-data-structure-for-players-4">4. Create a data structure for players</a></span><ul class="toc-item"><li><span><a href="#4.1" data-toc-modified-id="4.1-4.1">4.1</a></span></li><li><span><a href="#4.2" data-toc-modified-id="4.2-4.2">4.2</a></span></li></ul></li><li><span><a href="#5.-Add-captured-pokemon-for-each-player" data-toc-modified-id="5.-Add-captured-pokemon-for-each-player-5">5. Add captured pokemon for each player</a></span></li><li><span><a href="#6.-What-gyms-have-players-visited?" data-toc-modified-id="6.-What-gyms-have-players-visited?-6">6. What gyms have players visited?</a></span><ul class="toc-item"><li><span><a href="#6.1" data-toc-modified-id="6.1-6.1">6.1</a></span></li><li><span><a href="#6.2" data-toc-modified-id="6.2-6.2">6.2</a></span></li></ul></li><li><span><a href="#7.-Calculate-player-&quot;power&quot;." data-toc-modified-id="7.-Calculate-player-&quot;power&quot;.-7">7. Calculate player "power".</a></span></li><li><span><a href="#8.-Load-a-pokedex-file-containing-all-the-pokemon" data-toc-modified-id="8.-Load-a-pokedex-file-containing-all-the-pokemon-8">8. Load a pokedex file containing all the pokemon</a></span><ul class="toc-item"><li><span><a href="#8.1" data-toc-modified-id="8.1-8.1">8.1</a></span></li><li><span><a href="#8.2-Parse-the-raw-pokedex-with-list-comprehensions" data-toc-modified-id="8.2-Parse-the-raw-pokedex-with-list-comprehensions-8.2">8.2 Parse the raw pokedex with list comprehensions</a></span></li></ul></li><li><span><a href="#9.-Write-a-function-to-generate-the-full-pokedex" data-toc-modified-id="9.-Write-a-function-to-generate-the-full-pokedex-9">9. Write a function to generate the full pokedex</a></span></li><li><span><a href="#10.-Write-a-function-to-generate-a-&quot;filtered&quot;-pokedex" data-toc-modified-id="10.-Write-a-function-to-generate-a-&quot;filtered&quot;-pokedex-10">10. Write a function to generate a "filtered" pokedex</a></span></li><li><span><a href="#11.-Descriptive-statistics-on-the-prototype-pokedex" data-toc-modified-id="11.-Descriptive-statistics-on-the-prototype-pokedex-11">11. Descriptive statistics on the prototype pokedex</a></span><ul class="toc-item"><li><span><a href="#11.1" data-toc-modified-id="11.1-11.1">11.1</a></span></li><li><span><a href="#11.2" data-toc-modified-id="11.2-11.2">11.2</a></span></li></ul></li><li><span><a href="#12.-Calibrate-the-frequency-of-Pokemon" data-toc-modified-id="12.-Calibrate-the-frequency-of-Pokemon-12">12. Calibrate the frequency of Pokemon</a></span></li></ul></div>

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint
import random
from random import randint
import time

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of times played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
player_id_one=1
player_name_one='Alastair Tyson'
time_played_one=10.2
player_pokemon_one={}
gyms_visited_one=[]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_locations=['reddit.com','amazon.com',
               'twitter.com','linkedin.com',
               'ebay.com','netflix.com',
               'sporcle.com','stackoverflow.com',
               'github.com','quora.com']

# %%
gyms_visited_one.append(gym_locations[randint(0,10)])
gyms_visited_one.append(gym_locations[5])

# %%
print (gyms_visited_one)
# Out:
# ['linkedin.com', 'netflix.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves be dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex={
           1: {'name':'charmander',
               'type':'fire',
               'hp':39,
               'attack':52,
               'defense':43,
               'special attack':60,
               'special defense':50,
               'speed':65},
           2: {'name':'squirtle',
               'type':'water',
               'hp':44,
               'attack':48,
               'defense':65,
               'special attack':50,
               'special defense':64,
               'speed':43},
           3: {'name':'bulbasaur',
               'type':'grasspoison',
               'hp':45,
               'attack':49,
               'defense':49,
               'special attack':65,
               'special defense':65,
               'speed':45}
          }

# %%
pprint (pokedex)
# Out:
# {1: {'attack': 52,
#      'defense': 43,
#      'hp': 39,
#      'name': 'charmander',
#      'special attack': 60,
#      'special defense': 50,
#      'speed': 65,
#      'type': 'fire'},
#  2: {'attack': 48,
#      'defense': 65,
#      'hp': 44,
#      'name': 'squirtle',
#      'special attack': 50,
#      'special defense': 64,
#      'speed': 43,
#      'type': 'water'},
#  3: {'attack': 49,
#      'defense': 49,
#      'hp': 45,
#      'name': 'bulbasaur',
#      'special attack': 65,
#      'special defense': 65,
#      'speed': 45,
#      'type': 'grasspoison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and the values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players={ player_id_one: {'Player Name':player_name_one,
                          'Time Played (hours)':time_played_one,
                          'Player Pokemon':player_pokemon_one,
                          'Gyms Visited':gyms_visited_one}
                           }

# %%
pprint (players)
# Out:
# {1: {'Gyms Visited': ['linkedin.com', 'netflix.com'],
#      'Player Name': 'Alastair Tyson',
#      'Player Pokemon': {},
#      'Time Played (hours)': 10.2}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
players[2]={'Player Name':'Heather Tyson',
           'Time Played (hours)':5.1,
           'Player Pokemon':{},
           'Gyms Visited':[gym_locations[7],gym_locations[8]]}

# %%
pprint (players)
# Out:
# {1: {'Gyms Visited': ['linkedin.com', 'netflix.com'],
#      'Player Name': 'Alastair Tyson',
#      'Player Pokemon': {},
#      'Time Played (hours)': 10.2},
#  2: {'Gyms Visited': ['stackoverflow.com', 'github.com'],
#      'Player Name': 'Heather Tyson',
#      'Player Pokemon': {},
#      'Time Played (hours)': 5.1}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 a charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
players[1]['Player Pokemon']={2:pokedex[2]}
players[2]['Player Pokemon']={1:pokedex[1], 3:pokedex[3]}

# %% [markdown]
# I entered the pokemon as a list so later the command .update({}) can be used to add more pokemon to their party

# %%
pprint (players)
# Out:
# {1: {'Gyms Visited': ['linkedin.com', 'netflix.com'],
#      'Player Name': 'Alastair Tyson',
#      'Player Pokemon': {2: {'attack': 48,
#                             'defense': 65,
#                             'hp': 44,
#                             'name': 'squirtle',
#                             'special attack': 50,
#                             'special defense': 64,
#                             'speed': 43,
#                             'type': 'water'}},
#      'Time Played (hours)': 10.2},
#  2: {'Gyms Visited': ['stackoverflow.com', 'github.com'],
#      'Player Name': 'Heather Tyson',
#      'Player Pokemon': {1: {'attack': 52,
#                             'defense': 43,
#                             'hp': 39,
#                             'name': 'charmander',
#                             'special attack': 60,
#                             'special defense': 50,
#                             'speed': 65,
#                             'type': 'fire'},
# ...

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in gym_locations:
    for player in players:
        if gym in players[player]['Gyms Visited']:
            print (players[player]['Player Name']+ ' has visited ' + gym)
# Out:
# Alastair Tyson has visited linkedin.com
# Alastair Tyson has visited netflix.com
# Heather Tyson has visited stackoverflow.com
# Heather Tyson has visited github.com

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %%
count=0

# %%
for gym in gym_locations:
    for player in players:
        if gym in players[player]['Gyms Visited']:
            print (players[player]['Player Name']+ ' has visited ' + gym)
            count+=1
        else:
            count+=1
print ('This loop ran '+ str(count) + ' times')
# Out:
# Alastair Tyson has visited linkedin.com
# Alastair Tyson has visited netflix.com
# Heather Tyson has visited stackoverflow.com
# Heather Tyson has visited github.com
# This loop ran 20 times

# %% [markdown]
# Loop ran 20 times (10 x 2)
# With N gyms and N players the loop would run N x N times
#
# This is inefficient as it is looping through empty gyms (in our example there are 16 unsucessful loops). Instead I would iterate through the players and use an inner loop to iterate through the gyms and print which gyms had been visited by which players. This would therefore eliminate any empty loops.

# %%
count_two=0

# %%
for player in players:
  for gym in players[player]['Gyms Visited']:
    gym_visit=0
    if gym in gym_locations:
      gym_visit+=1
      count_two+=1
      print (gym + ' has been visited by ' + players[player]['Player Name'])
print ('This loop ran ' + str(count_two) + ' times')
# Out:
# linkedin.com has been visited by Alastair Tyson
# netflix.com has been visited by Alastair Tyson
# stackoverflow.com has been visited by Heather Tyson
# github.com has been visited by Heather Tyson
# This loop ran 4 times

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics of all their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %% [markdown]
# This function calls the info from the pokedex

# %%
def player_power(players,pokedex,player_id):
    """Function that takes information about player's Pokemon 
    and returns their power"""
    power=0
    for pokemon in players[player_id]['Player Pokemon']:
        for key in range(1,len(pokedex)+1):
            if players[player_id]['Player Pokemon'][pokemon]['name'] in\
            pokedex[key]['name']:
                power+=pokedex[key]['attack']+pokedex[key]['defense']
    print (players[player_id]['Player Name'] + "'s power is " + str(power))

# %%
for player in players:
    player_power(players,pokedex,player)
# Out:
# Alastair Tyson's power is 113
# Heather Tyson's power is 193

# %% [markdown]
# I also wrote a function which performed the calculation without going to the pokedex as the information is already contained in the players dictionary

# %%
def player_power_2(players,player_id):
    """Function that takes information about player's Pokemon 
    and returns their power"""
    power=0
    for pokemon in players[player_id]['Player Pokemon']:
        power+=players[player_id]['Player Pokemon'][pokemon]['attack'] +\
              players[player_id]['Player Pokemon'][pokemon]['defense']
    print (players[player_id]['Player Name'] + "'s power is " + str(power))
    return (power)

# %%
for player in players:
    player_power_2(players,player)
# Out:
# Alastair Tyson's power is 113
# Heather Tyson's power is 193

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of the list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %% [markdown]
# Cleaning the data and preparing it for iteration

# %%
raw_pd_clean=raw_pd.replace('\n',',').replace('"','').split(',')

# %%
raw=[]
for item in raw_pd_clean:
    if item.isdigit()==True:
        raw.append(float(item))
    else:
        raw.append(item)

# %%
poke=[]
for i in range(0,len(raw),10):
    poke.append(raw[i:i+10])
pprint (poke,width=500)
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0],
#  [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0],
# ...

# %% [markdown]
# Using a list comprehension

# %%
pokedex_complete=[raw[i:i+10] for i in range(0,len(raw),10)]

pprint (pokedex_complete,width=500)
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0],
#  [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0],
# ...

# %% [markdown]
# There are no empty cells in the csv, no need to replace with -1

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
pokedex_2=[[x for x in [float(item) if item.isdigit()== True else item for item in raw_pd.replace('\n',',').replace('"','').split(',')]][i:i+10]for i in range(0,len([x for x in [float(item) if item.isdigit()== True else item for item in raw_pd.replace('\n',',').replace('"','').split(',')]]),10)]
pprint (pokedex_2,width=500)
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0],
#  [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0],
#  [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0],
# ...

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. Create a unique key value for each entry in the pokemon dictionary.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
def pokedex_call(pokedex_2):
    pokedex_dict={pokedex_2.index(row):row for row in pokedex_2}
    return (pokedex_dict)

# %%
pokedex_dict=pokedex_call(pokedex_2)
pprint (pokedex_dict,width=500)
# Out:
# {0: ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'],
#  1: [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  2: [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  3: [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  4: [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0],
#  5: [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  6: [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  7: [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  8: [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0],
#  9: [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0],
#  10: [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0],
# ...

# %%
def pokemon_profile(pokedex,unique_id):
    """Function that calls information about a 
    pokemon given its key in the dictionary"""
    dict=pokedex_call(pokedex)
    return ([dict[0],dict[unique_id]])

# %%
pprint (pokemon_profile(pokedex_2,100),width=500)
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [92.0, 'Gastly', 'GhostPoison', 310.0, 30.0, 35.0, 30.0, 100.0, 35.0, 80.0]]

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified by a value that is greater than or equal to the value of the corresponding dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 25, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
attributes=['PokedexNumber', 'Name', 'Type', 'Total', 'HP',
            'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']

# %%
def query():
    pokedex_dict=pokedex_call(pokedex_2)
    print ('What values would you like to filter by? When finished type stop  ')
    check=False
    out={}
    #Keeps running until user has indicated they have finished choosing
    while check ==False:
        ask=input('Select Attribute: ').lower()
        try:
            if ask=='attack':
                attack=float(input('Attack value greater than: '))
                out['Attack']=attack
                check=False
            elif ask=='defense':
                defense=float(input('Defense value greater than: '))
                out['Defense']=defense
                check=False
            elif ask=='hp' or ask == 'health points':
                hp=float(input('HP value greater than: '))
                out['HP']=hp
                check=False
            elif ask=='total':
                total=float(input('Total value greater than: '))
                out['Total']=total
                check=False
            elif ask =='sp att' or ask == 'special attack':
                sp_att=float(input('Special Attack value greater than: '))
                out['SpecialAttack']=sp_att
                check=False
            elif ask == 'sp def' or ask =='special defense':
                sp_def=float(input('Special Defense value greater than: '))
                out['SpecialDefense']=sp_def
                check=False
            elif ask=='speed':
                speed=float(input('Speed value greater than: '))
                out['Speed']=speed
                check=False    
            elif ask=='name':
                nam=str(input('Pokemon name: ')).lower()
                out['Name']=nam
            elif ask=='type':
                #Users can specify up to two types
                pok_type_1=str(input('First Pokemon Type: ')).lower()
                #Corrects is user enters valid type but has not capitalised first letter
                lis_1=list(pok_type_1)
                first_1=lis_1[0].upper() 
                rest_1=lis_1[1:]
                rest_a=''
                for i in rest_1:
                    rest_a+=i
                type_1=first_1+rest_a
                pok_type_2=str(input('(Optional) Second Pokemon Type: ')).lower()
                try:
                    lis_2=list(pok_type_2)
                    first_2=lis_2[0].upper() 
                    rest_2=lis_2[1:]
                    rest_b=''
                    for i in rest_2:
                        rest_b+=i
                    type_2=first_2+rest_b
                except IndexError:
                    type_2=''
                out['Type']=type_1+type_2
                check=False
            elif ask=='stop':
                check=True
            else:
                print ('Invalid attribute')
                check=False
        except ValueError:
            return ('Invalid input')
    print ('Attributes to be filtered: ') 
    print (out)
    pokemon_out=[]
    pokemon_result=[]
    pokemon_final=[]
    #Defines default values that will be overwritten by user input
    default={'Attack':0,'Defense':0,'HP':0,'SpecialAttack':0,'SpecialDefense':0,
             'Speed':0,'Total':0}
    for key in out:
        if key in default:
            default[key]=out[key]       
    for i in range(1,len(pokedex_dict)):
        carry={}
        p_dict={}
        #Selcts all Pokemon whose values exceed indicated values
        if pokedex_dict[i][attributes.index('Attack')]>=default['Attack'] and pokedex_dict[i][attributes.index('Defense')]>=default['Defense'] and  pokedex_dict[i][attributes.index('HP')]>=default['HP'] and pokedex_dict[i][attributes.index('SpecialAttack')]>=default['SpecialAttack'] and pokedex_dict[i][attributes.index('SpecialDefense')]>=default['SpecialDefense'] and pokedex_dict[i][attributes.index('Speed')]>=default['Speed'] and pokedex_dict[i][attributes.index('Total')]>=default['Total']:
            carry['Attack']=pokedex_dict[i][5]
            carry['Defense']=pokedex_dict[i][6]
            carry['HP']=pokedex_dict[i][4]
            carry['Special Attack']=pokedex_dict[i][7]
            carry['Special Defense']=pokedex_dict[i][8]
            carry['Speed']=pokedex_dict[i][9]
            carry['Total']=pokedex_dict[i][3]
            carry['Type']=pokedex_dict[i][2]
            carry['Name']=pokedex_dict[i][1]
            p_dict[pokedex_dict[i][1]]=carry
            pokemon_out.append(p_dict)
    #Further filtering if user has selected 'Type'
    count=0
    if 'Type' in out:
        for j in range(len(pokemon_out)):
            pdict=pokemon_out[j]
            for k in pdict:
                if out['Type'] in pokemon_out[j][k]['Type']:
                    pokemon_result.append(pokemon_out[j])                          
    else:
        for i in range(len(pokemon_out)):   
            pokemon_result.append(pokemon_out[i])
    #Further filtering if user has selected 'Name'        
    if 'Name' in out:
        for pokemon in range(len(pokemon_result)):
            pcount=pokemon_result[pokemon]
            for item in pcount:
                if out['Name'] in pokemon_result[pokemon][item]['Name'].lower():
                    pokemon_final.append(pokemon_result[pokemon])
                    count+=1
    else:
        for i in range(len(pokemon_result)):
            pokemon_final.append(pokemon_result[i])
            count+=1
    many=str(count)
    print('Search yielded ' + many + ' results')
    print ('Results of search: ')
    pprint (pokemon_final,width=500)

# %%
query() #Runs the filter
# Out:
# What values would you like to filter by? When finished type stop
# Select Attribute: speed
# Speed value greater than: 70
# Select Attribute: stop
# Attributes to be filtered:
# {'Speed': 70.0}
# Search yielded 374 results
# Results of search:
# [{'Venusaur': {'Attack': 82.0, 'Defense': 83.0, 'HP': 80.0, 'Name': 'Venusaur', 'Special Attack': 100.0, 'Special Defense': 100.0, 'Speed': 80.0, 'Total': 525.0, 'Type': 'GrassPoison'}},
#  {'VenusaurMega Venusaur': {'Attack': 100.0, 'Defense': 123.0, 'HP': 80.0, 'Name': 'VenusaurMega Venusaur', 'Special Attack': 122.0, 'Special Defense': 120.0, 'Speed': 80.0, 'Total': 625.0, 'Type': 'GrassPoison'}},
#  {'Charmeleon': {'Attack': 64.0, 'Defense': 58.0, 'HP': 58.0, 'Name': 'Charmeleon', 'Special Attack': 80.0, 'Special Defense': 65.0, 'Speed': 80.0, 'Total': 405.0, 'Type': 'Fire'}},
# ...

# %% [markdown]
# 11. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# 11.1
#
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
header=pokedex_2[0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def stats(pokedex):
    #Function that prints mean and standard deviation
    #for Total column from pokedex that is passed in
    attr=[pokedex[j][3] for j in range(1,len(pokedex))]
    mean=np.mean(attr)
    sd=np.std(attr)
    out={'Mean':mean,'Standard Deviation':sd}
    return out

# %%
stand=stats(pokedex_2)
print (stand)
# Out:
# {'Mean': 435.1275, 'Standard Deviation': 119.96202000529168}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 11.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
#Calculates the Total value which is 3 standard deviations above the mean
Total_warning=435.1275+3*119.96202000529168
print(Total_warning)
# Out:
# 795.0135600158751

# %% [markdown]
# Mewtwo Mega Mewtwo X is overpowered as it has a Total of 800 (>795.0)

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 12. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
#Following code assumes Pokemon is guarenteed to appear at a gym
#and chance of appearing is independent of player strength

# %% [markdown]
# Consider Pokemon legendary if Total above 750 (as can be seen in histogram).
# Consider Pokemon powerful if Total more than 2 standard deviations above the mean.
# Consider Pokemon strong if Total more than 1 standard deviation above mean.
# Consider average if Total within one standard deviation of mean above.
# Consider weak is Total is below the mean

# %%
import seaborn as sns

# %%
#Printing a histogram of totals 
total=[pokedex_2[j][3] for j in range(1,len(pokedex_2))]
sns.distplot(total,kde=False,axlabel='Total',bins=25).set_title('Distribution of Pokemon Totals')
plt.axvline(np.mean(total),0,1000,label='Average >',color='blue')
plt.axvline((np.mean(total)+np.std(total)),0,1000,label='Strong >',color='purple')
plt.axvline((np.mean(total)+2*np.std(total)),0,1000,label='Powerful >',color='green')
plt.axvline(750,0,1000,label='Legendary >',color='orange')
plt.legend()
plt.show();

# %%
#Finding the Total values for each classification
legendary_total=stand['Mean']+2*stand['Standard Deviation']
powerful_total=stand['Mean']+stand['Standard Deviation']
lower_total=stand['Mean']-stand['Standard Deviation']
total_dict={'Two above':legendary_total,'One above':powerful_total}

# %% [markdown]
# Using query function, passing above attributes for Total yielded the following amounts for each category

# %%
classification=['Weak', 'Average','Strong', 'Powerful', 'Legendary']
#Calculates lower bound for each classification Total
totals={'Weak':0,'Average':stand['Mean'],'Strong':powerful_total,
        'Powerful':legendary_total,'Legendary':750}
#Calculates upper bound for each classification Total
totals_plus={'Weak':stand['Mean'],'Average':powerful_total,'Strong':legendary_total,
        'Powerful':750,'Legendary':1000}

# %%
#Creates a dictionary that for each classification
#returns the names and totals for each Pokemon of that class
class_dict={}
for item in classification:
    collect=[pokedex_2[i][1] 
         for i in range(1,len(pokedex_2)) 
         if pokedex_2[i][3] in range(int(totals[item]),int(totals_plus[item])) 
        ]
    class_dict[item]=collect

# %%
#Calculates how many Pokemon are in each classification
frequencies={item:len(class_dict[item]) for item in classification}
#I then define weighted frequencies to make weaker Pokemon classes more
#likely to appear. The numbers I chose work but could do with further
#calibration which I would do if I was bringing this product to market
weighted_frequencies={'Weak':400,'Average':270,'Strong':60,'Powerful':10,'Legendary':1}
weighted_sum=sum([weighted_frequencies[item] for item in classification])

# %% [markdown]
# Then to calculate the individual chance of any Pokemon appearing I multiplied the probability of that classification being picked from the weighted frequency by the probability of picking a random Pokemon from that classification.
#
# This assumes all Pokemon within a classification have the same chance of being picked

# %%
#Function that calculate the probability of a Pokemon appearing given its ID
def probability_check(id):
    name=pokedex_dict[id][1]
    for level in classification:
        if name in class_dict[level]:
            p=round((weighted_frequencies[level]/weighted_sum)*100,2)
            print ('Classification: ' + level +' - Chance: ' + str(p) +'%')
            print ('Chance of ' + name + ' appearing: ' + str(round((1/frequencies[level])*(weighted_frequencies[level]/weighted_sum)*100,2)) + '%')

# %%
probability_check(154)
# Out:
# Classification: Average - Chance: 36.44%
# Chance of Aerodactyl appearing: 0.12%

# %% [markdown]
# Running ID #154 through probability check would return:
# Aerodactyl, classification: Average and probability of 0.09% of appearing.
#
# Therefore, using weighted frequencies: there is a 36.4% chance of encountering an 'Average' strength Pokemon. The chance of seeing an Aerodactyl specifically is 0.12%

# %% [markdown]
# This assumes that all Pokemon are available at every gym for every player. The following code will generate n Pokemon under these conditions

# %%
#Stores lower cumulative probabilities for later reference
cumulative_prob={'Weak':0,'Average':400,'Strong':670,
        'Powerful':730,'Legendary':740}
#Stores upper cumulative probabilities for later reference
cumulative_prob_plus={'Weak':400,'Average':670,'Strong':730,
        'Powerful':740,'Legendary':741}

# %%
#Generates n Pokemon based on their relative probabilities of appearing
def pokemon_encounter(number):
    while number > 0:
        check=random.uniform(0,742)
        for level in classification:
            if int(check) in range(int(cumulative_prob[level]),int(cumulative_prob_plus[level])):
                pokemon=class_dict[level]
        encounter=random.choice(pokemon)
        print ('A wild ' + encounter + ' appears!')
        time.sleep(2)
        number-=1

# %%
pokemon_encounter(5)
# Out:
# A wild Surskit appears!
# A wild Diggersby appears!
# A wild Snubbull appears!
# A wild Slakoth appears!
# A wild Duskull appears!

# %% [markdown]
# I believe it is unrealistic to assume that every Pokemon will be present at every gym as this would make a frustrating experience for the user as they would be unlikely to encounter the Pokemon they want and more often than not will encounter weak Pokemon, even if they are a strong player.
#
# What if you were to limit 100 Pokemon to each gym and make it so more powerful players are more likely to encounter more powerful Pokemon?
#
# The following code defines a function that randommly assigns 100 unique Pokemon to each gym roughly in the proportion of the classifications shown in the dictionary frequencies variable defined earlier.
#
# It then takes into account player power as defined earlier in the workbook and for each class of player gives them a likilihood of encountering a particular Pokemon if they go to that gym.

# %%
#Creates a dictionary for each gym that randommly asigns
#100 Pokemon. The Pokemon 'strengths' will be distributed 
#according to the probabilities calculated earlier
frequencies_new={'Weak': 48, 'Average': 36, 'Strong': 12,
             'Powerful': 3, 'Legendary': 1}
gym_dict={}
for gym in gym_locations:
    gym_pokemon={}
    for item in classification:
        n=int(frequencies_new[item])
        collect=[]
        while n>0:
            pool=random.choice(class_dict[item])
            if pool not in collect:
                collect.append(pool)
                n-=1
        gym_pokemon[item]=collect          
    gym_dict[gym]=gym_pokemon
#Enter gym_dict['gym name'] to see what Pokemon are currently present at that gym

# %%
#defines % chance of Pokemon not appearing at a gym
no_appear={'Weak':2,'Average':3,'Strong':4,'Powerful':5,'Legendary':6}

# %%
#Generates power levels so players can be classified 
power_cutoff={item: totals[item]*1.5 for item in totals}
power_cutoff_plus={item:totals_plus[item]*1.5 for item in totals_plus}
#Dictionary storing cumulative probabilities for each player classification
probabilities_upper={'Weak':[72,92,96,99,100],
               'Average':[43,76,91,97,100],
               'Strong':[29,64,84,94,100],
               'Powerful':[15,35,70,92,100],
               'Legendary':[11,23,49,85,100]
              }
probabilities_lower={'Weak':[2,72,92,96,99],
               'Average':[3,43,76,91,97],
               'Strong':[4,29,64,84,94],
               'Powerful':[5,15,35,70,92],
               'Legendary':[6,11,23,49,92]
              }
#These are in the order: None, Weak, Average, Strong, Powerful, Legendary

# %%
probs_weights={'Weak':[70,20,4,3,1],
               'Average':[40,33,15,6,3],
               'Strong':[25,34,20,10,6],
               'Powerful':[10,20,35,22,8],
               'Legendary':[5,12,26,36,15]
              }

# %%
#New players list including test players for each classification
test_players={ 1: {'Player Name':'Alastair Tyson',                         
                          'Player Pokemon':{1:{'attack':80,
                                                                  'defense':50}}},
               2: {'Player Name':'Heather Tyson',                         
                          'Player Pokemon':{1:{'attack':100,
                                                                 'defense':93}}},
               3: {'Player Name':'Average Player',                         
                          'Player Pokemon':{1:{'attack':350,
                                                               'defense':350}}},
               4: {'Player Name':'Strong Player',                         
                          'Player Pokemon':{1:{'attack':450,
                                                               'defense':450}}},
               5: {'Player Name':'Powerful Player',                         
                          'Player Pokemon':{1:{'attack':550,
                                                               'defense':550}}},
               6: {'Player Name':'Legendary Player',                         
                          'Player Pokemon':{1:{'attack':600,
                                                               'defense':600}}}         
                           }

# %%
#Creates a function that takes player name and website as an input
#and randommly generates a Pokemon encounter suitable to their level

#Enter random when prompted for website to receive random gym
def encounter_website():
    try:
        player=int(input('Enter player ID: '))
        number=int(input('How many times would you like to search for a Pokemon? '))
        gym=str(input('Enter website: ')).lower()
        if gym=='random':
            gym=random.choice(gym_locations)
        if '.com' not in gym:
            return ('Enter full website name')
        if gym not in gym_locations:
            return ('No gym exists at that location')
    except ValueError:
        return ('Incorrect input')
    try:
        player_power=player_power_2(test_players,player)
    except KeyError:
        return ('No player exists with that ID')
    for level in power_cutoff:
        if player_power in range(int(power_cutoff[level]),int(power_cutoff_plus[level])):
            print ("Player's power is " + level)
            while number>0:
                roll=int(random.uniform(0,100))
                if roll in range(0,int(no_appear[level])):
                    number-=1
                    print ('No Pokemon Appear, ' + str(no_appear[level]) +'%')
                else:
                    for i in range(0,5):
                        if roll in range(int(probabilities_lower[level][i]),int(probabilities_upper[level][i])):
                            total=classification[i]
                            pool=gym_dict[gym][total]
                            collect=random.choice(pool)
                            print('A wild ' + collect + ' appears at ' + gym +'!')
                            for index in range(1,len(pokedex_dict)):
                                if pokedex_dict[index][1]==collect:
                                    print ('Attack: ' + str(pokedex_dict[index][5]) + ',' +
                                       ' Defense: ' + str(pokedex_dict[index][6]) + ',' +
                                       ' Special Attack: ' + str(pokedex_dict[index][7]) + ',' +
                                       ' Special Defense: ' + str(pokedex_dict[index][8]) + ',' +
                                       ' Health Points: ' + str(pokedex_dict[index][4]) + ',' +
                                       ' Speed: ' + str(pokedex_dict[index][9]) + ',' +
                                       ' Type: ' + str(pokedex_dict[index][2]) + ',' +
                                       ' Classification: ' + total)
                                    probability=round((1/frequencies_new[total]) * (probs_weights[level][i]/100)*100,2)
                                    print ('Encounter chance ' + str(probability) + '%')
                                    time.sleep(2)
                                    number-=1

# %%
encounter_website()
# Out:
# Enter player ID: 2
# How many times would you like to search for a Pokemon? 3
# Enter website: random
# Heather Tyson's power is 193
# Player's power is Weak
# A wild Seviper appears at ebay.com!
# Attack: 100.0, Defense: 60.0, Special Attack: 100.0, Special Defense: 60.0, Health Points: 73.0, Speed: 65.0, Type: Poison, Classification: Average
# Encounter chance 0.56%
# A wild Meganium appears at ebay.com!
# Attack: 82.0, Defense: 100.0, Special Attack: 83.0, Special Defense: 100.0, Health Points: 80.0, Speed: 80.0, Type: Grass, Classification: Average
# Encounter chance 0.56%
# A wild Ho-oh appears at ebay.com!
# Attack: 130.0, Defense: 90.0, Special Attack: 110.0, Special Defense: 154.0, Health Points: 106.0, Speed: 90.0, Type: FireFlying, Classification: Powerful
# Encounter chance 1.0%

# %% [markdown]
# By reducing the amount of Pokemon in each gym, a weak player now has a 0.54% chance (increased from 0.12%) of encountering Aerodactyl (provided it is present at that gym).
#
# This model also assumes that any Pokemon within a class are equally likely to appear, as long as they are at that gym. To extend further, I could consider each individual Pokemon an individual probaility of appearing based on their Total, with stronger Pokemon being rarer to find. However, I like the model I have come up with as it allows for player progression as well as limiting the amount of Pokemon at each gym which could be refreshed every week for example.

# %%
#Creates a dictionary showing the probability of encountering a specific
#Pokemon of each type for each level of player
prob_dist_level={}
for level in classification:
    prob=[]
    for i in range(0,5):
        prob.append(probs_weights[level][i]/100)
    prob_dist_level[level]=prob
prob_dist_level

probability_distribution_per_player={}
for item in prob_dist_level:
    pool=[]
    
    pool.append(round(prob_dist_level[item][0]*(1/48)*100,2))
    pool.append(round(prob_dist_level[item][1]*(1/37)*100,2))
    pool.append(round(prob_dist_level[item][2]*(1/12)*100,2))
    pool.append(round(prob_dist_level[item][3]*(1/3)*100,2))
    pool.append(round(prob_dist_level[item][4]*(1/1)*100,2))
    probability_distribution_per_player[item]=pool
    

probability_distribution_per_player
# Out:
# {'Weak': [1.46, 0.54, 0.33, 1.0, 1.0],
#  'Average': [0.83, 0.89, 1.25, 2.0, 3.0],
#  'Strong': [0.52, 0.92, 1.67, 3.33, 6.0],
#  'Powerful': [0.21, 0.54, 2.92, 7.33, 8.0],
#  'Legendary': [0.1, 0.32, 2.17, 12.0, 15.0]}

# %% [markdown]
# Keep in mind, these probabilities are for encountering one specific Pokemon given their classification. The probability of encountering a Pokemon of a specific classification is determined by the weighted frequencies defined in probabilities_upper/probabilities_lower.
#
# For example, the 'Legendary' Pokemon for a weak player is nearly twice as likely to appear than any specific 'Average' Pokemon. However, the probability of seeing any 'Average' Pokemon is 20 times more likely than seeing a Legendary for a weak player.
